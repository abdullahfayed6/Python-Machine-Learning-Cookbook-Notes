# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('titanic.csv')
df_new = df[['Name', 'Pclass', 'Age', 'Sex', 'Survived']].copy()
df_new['PClass'] = df_new['Pclass'].map({1: '1st', 2: '2nd', 3: '3rd'})
df_new['SexCode'] = df_new['Sex'].map({'female': 1, 'male': 0})
df = df_new[['Name', 'PClass', 'Age', 'Sex', 'Survived', 'SexCode']]

df.head(5)
# Out:
#                                                 Name PClass   Age     Sex  \
# 0                            Braund, Mr. Owen Harris    3rd  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1st  38.0  female
# 2                             Heikkinen, Miss. Laina    3rd  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1st  35.0  female
# 4                           Allen, Mr. William Henry    3rd  35.0    male
#
#    Survived  SexCode
# 0         0        0
# 1         1        1
# 2         1        1
# 3         1        1
# 4         0        0

# %% [markdown]
# # **Describing the Data**

# %%
# Show dimenstions
df.shape
# Out:
# (891, 6)

# %%
# Show statistics
df.describe()
# Out:
#               Age    Survived     SexCode
# count  714.000000  891.000000  891.000000
# mean    29.699118    0.383838    0.352413
# std     14.526497    0.486592    0.477990
# min      0.420000    0.000000    0.000000
# 25%     20.125000    0.000000    0.000000
# 50%     28.000000    0.000000    0.000000
# 75%     38.000000    1.000000    1.000000
# max     80.000000    1.000000    1.000000

# %% [markdown]
# # **Navigating DataFrames**

# %%
# Select first row
df.iloc[0]
# Out:
# Name        Braund, Mr. Owen Harris
# PClass                          3rd
# Age                            22.0
# Sex                            male
# Survived                          0
# SexCode                           0
# Name: 0, dtype: object

# %%
# Select three rows
df.iloc[1:4]
# Out:
#                                                 Name PClass   Age     Sex  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1st  38.0  female
# 2                             Heikkinen, Miss. Laina    3rd  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1st  35.0  female
#
#    Survived  SexCode
# 1         1        1
# 2         1        1
# 3         1        1

# %%
# Select to row u want
df.iloc[:4]
# Out:
#                                                 Name PClass   Age     Sex  \
# 0                            Braund, Mr. Owen Harris    3rd  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1st  38.0  female
# 2                             Heikkinen, Miss. Laina    3rd  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1st  35.0  female
#
#    Survived  SexCode
# 0         0        0
# 1         1        1
# 2         1        1
# 3         1        1

# %%
# Set index
df = df.set_index(df['Name'])
# Show row
df.loc['Braund, Mr. Owen Harris']
# Out:
# Name        Braund, Mr. Owen Harris
# PClass                          3rd
# Age                            22.0
# Sex                            male
# Survived                          0
# SexCode                           0
# Name: Braund, Mr. Owen Harris, dtype: object

# %% [markdown]
# # **Selecting Rows Based on Conditionals**

# %%
df = df_new[['Name', 'PClass', 'Age', 'Sex', 'Survived', 'SexCode']]

# %%
# Show top three rows where column 'sex' is 'female'
df[df['Sex'] == 'female'].head(3)
# Out:
#                                                 Name PClass   Age     Sex  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1st  38.0  female
# 2                             Heikkinen, Miss. Laina    3rd  26.0  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1st  35.0  female
#
#    Survived  SexCode
# 1         1        1
# 2         1        1
# 3         1        1

# %%
# Filter rows with multiple conditions
df[(df['Sex'] == 'female') & (df['Age'] >= 63)]
# Out:
#                                   Name PClass   Age     Sex  Survived  SexCode
# 275  Andrews, Miss. Kornelia Theodosia    1st  63.0  female         1        1
# 483             Turkula, Mrs. (Hedwig)    3rd  63.0  female         1        1

# %% [markdown]
# # **Replacing Values**

# %%
df = df_new[['Name', 'PClass', 'Age', 'Sex', 'Survived', 'SexCode']]

# %%
# Replace "female" and "male with "Woman" and "Man"
df['Sex'].replace(['female', 'male'], ['Woman', 'Man']).head(3)
# Out:
# 0      Man
# 1    Woman
# 2    Woman
# Name: Sex, dtype: object

# %%
# Replace values
df.replace(1, 'One').head(3)
# Out:
#                                                 Name PClass   Age     Sex  \
# 0                            Braund, Mr. Owen Harris    3rd  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1st  38.0  female
# 2                             Heikkinen, Miss. Laina    3rd  26.0  female
#
#   Survived SexCode
# 0        0       0
# 1      One     One
# 2      One     One

# %%
# Replace values
df.replace(r'1st', 'First', regex=True).head(3)
# Out:
#                                                 Name PClass   Age     Sex  \
# 0                            Braund, Mr. Owen Harris    3rd  22.0    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  First  38.0  female
# 2                             Heikkinen, Miss. Laina    3rd  26.0  female
#
#    Survived  SexCode
# 0         0        0
# 1         1        1
# 2         1        1

# %% [markdown]
# # **Renaming Columns**

# %%
df = df_new[['Name', 'PClass', 'Age', 'Sex', 'Survived', 'SexCode']]

# %%
# Rename column
df.rename(columns={'PClass': 'Passenger Class', 'Sex': 'Gender'}).head(3)
# Out:
#                                                 Name Passenger Class   Age  \
# 0                            Braund, Mr. Owen Harris             3rd  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...             1st  38.0
# 2                             Heikkinen, Miss. Laina             3rd  26.0
#
#    Gender  Survived  SexCode
# 0    male         0        0
# 1  female         1        1
# 2  female         1        1

# %% [markdown]
# # **Finding the Minimum, Maximum, Sum, Average, and Count**

# %%
df = df_new[['Name', 'PClass', 'Age', 'Sex', 'Survived', 'SexCode']]

# %%
# Calculate statistics
print('Maximum:', df['Age'].max())
print('Minimum:', df['Age'].min())
print('Mean:', df['Age'].mean())
print('Sum:', df['Age'].sum())
print('Count:', df['Age'].count())
# Out:
# Maximum: 80.0
# Minimum: 0.42
# Mean: 29.69911764705882
# Sum: 21205.17
# Count: 714

# %% [markdown]
# In addition to the statistics used in the solution, pandas offers variance (var), standard
# deviation (std), kurtosis (kurt), skewness (skew), standard error of the mean
# (sem), mode (mode), median (median), and a number of others.

# %%
# Show counts
df.count()
# Out:
# Name        891
# PClass      891
# Age         714
# Sex         891
# Survived    891
# SexCode     891
# dtype: int64

# %% [markdown]
# # **Finding Unique Values**

# %%
# Select unique values
df['Sex'].unique() # nunique() for number
# Out:
# array(['male', 'female'], dtype=object)

# %%
# Show counts
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# # **Missing Values**

# %%
df = df_new[['Name', 'PClass', 'Age', 'Sex', 'Survived', 'SexCode']]

# %%
## Select missing values
df[df['Age'].isnull()].head(3)
# Out:
#                             Name PClass  Age     Sex  Survived  SexCode
# 5               Moran, Mr. James    3rd  NaN    male         0        0
# 17  Williams, Mr. Charles Eugene    2nd  NaN    male         1        0
# 19       Masselmani, Mrs. Fatima    3rd  NaN  female         1        1

# %%
df.isna().sum()
# Out:
# Name          0
# PClass        0
# Age         177
# Sex           0
# Survived      0
# SexCode       0
# dtype: int64

# %% [markdown]
# * isnull() ' NaN ' for numbers only
# * np.nan can include strings

# %% [markdown]
# # **Deleting a Column And Deleting a Row**

# %%
df = df_new[['Name', 'PClass', 'Age', 'Sex', 'Survived', 'SexCode']]

# %%
# Delete column
df.drop('Age', axis=1).head(2)
# Out:
#                                                 Name PClass     Sex  Survived  \
# 0                            Braund, Mr. Owen Harris    3rd    male         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1st  female         1
#
#    SexCode
# 0        0
# 1        1

# %%
# Drop column by index
df.drop(df.columns[1], axis=1).head(2)
# Out:
#                                                 Name   Age     Sex  Survived  \
# 0                            Braund, Mr. Owen Harris  22.0    male         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female         1
#
#    SexCode
# 0        0
# 1        1

# %% [markdown]
# **try don't use inplace = True , This can
# lead to problems in more complex data processing pipelines**
#
# ---
# * axis=1 shrink columns
# * axis=0 shrink rows

# %%
# Delete rows
df[df['Sex'] != 'male'].head(2)
# Out:
#                                                 Name PClass   Age     Sex  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1st  38.0  female
# 2                             Heikkinen, Miss. Laina    3rd  26.0  female
#
#    Survived  SexCode
# 1         1        1
# 2         1        1

# %%
df[df['Name'] != 'Braund, Mr. Owen Harris'].head(2)
# Out:
#                                                 Name PClass   Age     Sex  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1st  38.0  female
# 2                             Heikkinen, Miss. Laina    3rd  26.0  female
#
#    Survived  SexCode
# 1         1        1
# 2         1        1

# %%
df[df.index != 1].head(2)
# Out:
#                       Name PClass   Age     Sex  Survived  SexCode
# 0  Braund, Mr. Owen Harris    3rd  22.0    male         0        0
# 2   Heikkinen, Miss. Laina    3rd  26.0  female         1        1

# %%
df.drop([0, 1] , axis=0).head(2)
# Out:
#                                            Name PClass   Age     Sex  \
# 2                        Heikkinen, Miss. Laina    3rd  26.0  female
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)    1st  35.0  female
#
#    Survived  SexCode
# 2         1        1
# 3         1        1

# %% [markdown]
# **more practical method is simply to wrap a
# boolean condition inside df[ ].**

# %% [markdown]
# # **Dropping Duplicate Rows**

# %%
df = df_new[['Name', 'PClass', 'Age', 'Sex', 'Survived', 'SexCode']]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)
# Out:
# /tmp/ipython-input-88-3006716147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %% [markdown]
# **Optional Parameters:**
# * **subset=['col1', 'col2']**: Only consider certain columns when checking for duplicates.
# * **keep='first'** (default): Keep first occurrence.
# * **keep='last'**: Keep last occurrence.
# * **keep=False**: Drop all duplicates.

# %% [markdown]
# # **Grouping Rows by Values**

# %%
df = df_new[['Name', 'PClass', 'Age', 'Sex', 'Survived', 'SexCode']]

# %%
# Group rows by the values of the column 'Sex', calculate mean of each group
df.groupby('Sex')[['Age', 'Survived', 'SexCode']].mean()
# Out:
#               Age  Survived  SexCode
# Sex
# female  27.915709  0.742038      1.0
# male    30.726645  0.188908      0.0

# %%
# Group rows, count rows
df.groupby('Survived')['Name'].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: Name, dtype: int64

# %%
# Group rows, calculate mean
df.groupby(['Survived','Sex'])['Age'].mean()
# Out:
# Survived  Sex
# 0         female    25.046875
#           male      31.618056
# 1         female    28.847716
#           male      27.276022
# Name: Age, dtype: float64

# %% [markdown]
# # **Looping Over a Column**

# %%
# Print first three names uppercased
for name in df['Name'][0:3]:
  print(name.upper())
# Out:
# BRAUND, MR. OWEN HARRIS
# CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS THAYER)
# HEIKKINEN, MISS. LAINA

# %%
# We can also use list comprehensions
[name.upper() for name in df['Name'][0:3]]
# Out:
# ['BRAUND, MR. OWEN HARRIS',
#  'CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS THAYER)',
#  'HEIKKINEN, MISS. LAINA']

# %% [markdown]
# # **Applying a Function Over All Elements in a Column**

# %%
def uppercase(x):
  return x.upper()
# Apply function, show three rows
df['Name'].apply(uppercase)[0:3]
# Out:
# 0                              BRAUND, MR. OWEN HARRIS
# 1    CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                               HEIKKINEN, MISS. LAINA
# Name: Name, dtype: object

# %% [markdown]
# # **Applying a Function to Groups**

# %% [markdown]
# If you have grouped rows using groupby and want to apply a function to each group use apply + lambda

# %%
# Group rows, apply function to groups
df.groupby('Sex').apply(lambda x: x.count())
# Out:
# /tmp/ipython-input-111-3980447101.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('Sex').apply(lambda x: x.count())
#         Name  PClass  Age  Sex  Survived  SexCode
# Sex
# female   314     314  261  314       314      314
# male     577     577  453  577       577      577

# %% [markdown]
# # **Concatenating DataFrames**

# %%
data_a = {'id': ['1', '2', '3'],
'first': ['Alex', 'Amy', 'Allen'],
'last': ['Anderson', 'Ackerman', 'Ali']}

data_b = {'id': ['4', '5', '6'],
'first': ['Billy', 'Brian', 'Bran'],
'last': ['Bonder', 'Black', 'Balwner']}

df_a = pd.DataFrame(data_a, columns = ['id', 'first', 'last'])
df_b = pd.DataFrame(data_b, columns = ['id', 'first', 'last'])

# %%
# Concatenate DataFrames by rows
pd.concat([df_a, df_b], axis=0)
# Out:
#   id  first      last
# 0  1   Alex  Anderson
# 1  2    Amy  Ackerman
# 2  3  Allen       Ali
# 0  4  Billy    Bonder
# 1  5  Brian     Black
# 2  6   Bran   Balwner

# %%
# Concatenate DataFrames by columns
pd.concat([df_a, df_b], axis=1)
# Out:
#   id  first      last id  first     last
# 0  1   Alex  Anderson  4  Billy   Bonder
# 1  2    Amy  Ackerman  5  Brian    Black
# 2  3  Allen       Ali  6   Bran  Balwner

# %% [markdown]
# # **Merging DataFrames**

# %%
employee_data = {'employee_id': ['1', '2', '3', '4'],
'name': ['Amy Jones', 'Allen Keys', 'Alice Bees','Tim Horton']}

sales_data = {'employee_id': ['3', '4', '5', '6'],
'total_sales': [23456, 2512, 2345, 1455]}

df_employees = pd.DataFrame(employee_data, columns = ['employee_id','name'])
df_sales = pd.DataFrame(sales_data, columns = ['employee_id','total_sales'])

# %%
# Merge DataFrames
pd.merge(df_employees, df_sales, on='employee_id')
# Out:
#   employee_id        name  total_sales
# 0           3  Alice Bees        23456
# 1           4  Tim Horton         2512

# %% [markdown]
# **merge defaults to inner joins**

# %%
# Outer merge DataFrames
pd.merge(df_employees, df_sales, on='employee_id', how='outer')
# Out:
#   employee_id        name  total_sales
# 0           1   Amy Jones          NaN
# 1           2  Allen Keys          NaN
# 2           3  Alice Bees      23456.0
# 3           4  Tim Horton       2512.0
# 4           5         NaN       2345.0
# 5           6         NaN       1455.0

# %%
# Left merge DataFrames
pd.merge(df_employees, df_sales, on='employee_id', how='left')
# Out:
#   employee_id        name  total_sales
# 0           1   Amy Jones          NaN
# 1           2  Allen Keys          NaN
# 2           3  Alice Bees      23456.0
# 3           4  Tim Horton       2512.0

# %%
# Right merge DataFrames
pd.merge(df_employees, df_sales, on='employee_id', how='right')
# Out:
#   employee_id        name  total_sales
# 0           3  Alice Bees        23456
# 1           4  Tim Horton         2512
# 2           5         NaN         2345
# 3           6         NaN         1455
